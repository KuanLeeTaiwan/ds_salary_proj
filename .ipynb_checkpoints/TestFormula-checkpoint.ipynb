# %%
import glassdoorscraper
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
keyword = 'Data Scientist'
path = "C:/Users/momo8/Documents/ds_salary_proj/chromedriver.exe"
df = glassdoorscraper.glassdoorscraper(path,keyword,10000,30)

# %%
df = pd.DataFrame(df)

# %%
df.to_csv('glassdoor.csv')

# %%
import pandas as pd
import numpy as np
import glassdoorscraper 
import matplotlib.pyplot as plt
import plotly.express as px
df = pd.read_csv('glassdoor.csv',header=0)
df =df.drop(columns='Unnamed: 0')

# %%
from collections import Counter 

str1 = "the dogs barked"
stringTokenDict = { key : value for key, value in Counter(str1.split()).items() } 

print(stringTokenDict['dogs']) 
#This dictionary contains all words & their respective count
# Out:
# 1

# %%
df = pd.read_csv('rawdata.csv',header=0)
df.drop(columns=['Unnamed: 0','Unnamed: 0.1'],inplace=True)

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import spacy
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd


nlp = spacy.load('en_core_web_sm')
dfreq = pd.DataFrame(df.groupby('Industry')['Dscrb'].sum()).reset_index()
listA = []

fig = make_subplots(rows=2, cols=1)
for x in range(0,41): 
    doc = nlp(dfreq.iloc[x,1])
    nouns = [token.text
         for token in doc
         if (not token.is_stop and
             not token.is_punct and
             token.pos_ == "NOUN")]
    word_freq = Counter(nouns)
    common_words = word_freq.most_common(10)
    listA.append(common_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20112/3085419175.py in <module>
#       9
#      10 nlp = spacy.load('en_core_web_sm')
# ---> 11 dfreq = pd.DataFrame(df.groupby('Industry')['Dscrb'].sum()).reset_index()
#      12 listA = []
#      13
#
# NameError: name 'df' is not defined

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Manage App Execution Aliases.

# %%
dd =pd.DataFrame(listA,index=dfreq['Industry'])
dd = dd.T
#px.bar(dd['Accounting'], x=dd['Accounting'][:][1][1], y=dd['Accounting'][:][1][0])
for x in dd.columns:
    a, b = zip(*dd[x])
    fig = px.bar(dd,x=a, y=b)
    fig.show()
dd
# Out:
# <div>                            <div id="79a6f405-be2a-4c9e-8818-0da110395521" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79a6f405-be2a-4c9e-8818-0da110395521")) {                    Plotly.newPlot(                        "79a6f405-be2a-4c9e-8818-0da110395521",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["business", "solutions", "analytics", "Location", "Responsibilities", "reporting", "customer", "segmentation", "optimization", "test"], "xaxis": "x", "y": [8, 8, 8, 4, 4, 4, 4, 4, 4, 4], "yaxis": "y"}],                  
# ...

# %%
dd
# Out:
# Industry             Accounting Advertising & Marketing Aerospace & Defense  \
# 0                 (business, 8)         (marketing, 52)   (experience, 372)
# 1                (solutions, 8)          (services, 48)         (data, 322)
# 2                (analytics, 8)         (customers, 42)        (years, 255)
# 3                 (Location, 4)              (data, 34)    (employees, 254)
# 4         (Responsibilities, 4)           (clients, 34)     (business, 200)
# 5                (reporting, 4)              (role, 30)     (position, 193)
# 6                 (customer, 4)           (company, 30)         (work, 172)
# 7             (segmentation, 4)          (customer, 30)    (analytics, 164)
# 8             (optimization, 4)        (experience, 30)      (history, 156)
# 9                     (test, 4)             (suite, 28)      (machine, 122)
#
# Industry Banks & Credit Unions Biotech & Pharmaceuticals  \
# 0                 (things, 56)            (research, 38)
# ...

# %%
Figure.print_grid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_53216/3717471192.py in <module>
# ----> 1 Figure.print_grid
#
# NameError: name 'Figure' is not defined

# %%
words = [token.text
         for token in doc
         if not token.is_stop and not token.is_punct]
# Out:
# Dscrb
